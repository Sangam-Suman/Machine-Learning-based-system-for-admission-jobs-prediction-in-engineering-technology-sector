# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import packages
import pandas as pd
import numpy as np

#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#read the file
df = pd.read_csv('/content/drive/MyDrive/Jobs_and_admission_prediction/ML/college admission prediction.csv')

#print the head
df.head()
# Out:
#    Year  10th Marks  12th Marks  12th Division  AIEEE Rank  \
# 0  2015          95          92              2         100
# 1  2015          75          88              3        1023
# 2  2015          83          84              6        2935
# 3  2015          75          91              8        5647
# 4  2015          94          94              9        3564
#
#                       College
# 0                   IIT delhi
# 1                 VIT vellore
# 2               Ahemedabad IT
# 3  University college of ENGG
# 4              SRMIST chennai

# %%
college=np.unique(df['College'])
print(college)
clg_code=[]
for i in range(len(college)):
    clg_code.append(i+1)

# clg_code
df['College']=df['College'].replace(college,clg_code)
bak_college=np.array(df['College'])
df.head()
# Out:
# ['Ahemedabad IT' 'BIT Mesra' 'BITS pilani' 'BMS college of ENGG'
#  'DTU delhi' 'HBUT kanpur' 'IIEST shibpur' 'IIIT hydrabad' 'IIT Bombay'
#  'IIT bhilai' 'IIT delhi' 'IIT goa' 'IIT guwahati' 'IIT hydrabad'
#  'IIT indore' 'IIT jammu' 'IIT jodhpur' 'IIT kanpur' 'IIT kharagpur'
#  'IIT mandi' 'IIT palakkad' 'IIT ropar' 'IIT tirupati'
#  'Jadavpur Univversity' 'KLEF hydrabad' 'MNIT jaipur' 'MNNIT allahabad'
#  'MSIT' 'Manipal IT' 'NIT trichy' 'NIT warangal' 'NMIMS'
#  'Netaji Subhas IT' 'S O A  university' 'SRMIST chennai'
#  'SSN college of ENGG' 'University college of ENGG' 'VIT vellore']
#    Year  10th Marks  12th Marks  12th Division  AIEEE Rank  College
# 0  2015          95          92              2         100       11
# 1  2015          75          88              3        1023       38
# 2  2015          83          84              6        2935        1
# 3  2015          75          91              8        5647       37
# 4  2015          94          94              9        3564       35

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# Using only one feature
x = df.iloc[:, 4].values
y = df.iloc[:, 5].values

# Split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state=0)

print('Shape of X_train:: ', x_train.shape)
print('Shape of y_train:: ', y_train.shape)
print('Shape of X_test:: ', x_test.shape)
print('Shape of y_test:: ', y_test.shape)

x_train= x_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)

print('\nShape of X_train:: ', x_train.shape)
print('Shape of y_train:: ', y_train.shape)
print('Shape of X_test:: ', x_test.shape)
print('Shape of y_test:: ', y_test.shape)
# Out:
# Shape of X_train::  (803,)
# Shape of y_train::  (803,)
# Shape of X_test::  (201,)
# Shape of y_test::  (201,)
#
# Shape of X_train::  (803, 1)
# Shape of y_train::  (803,)
# Shape of X_test::  (201, 1)
# Shape of y_test::  (201,)

# %%
# !pip install joblib
import joblib
model = linear_model.LinearRegression()
model.fit(x_train, y_train)
# Save the model
joblib.dump(model, "/content/drive/MyDrive/Jobs_and_admission_prediction/ML/linear_model.pkl")
y_pred = model.predict(x_test)

print('Coefficient:', model.coef_)
print("RMSE: %.2f" % np.sqrt(np.mean((model.predict(x_test) - y_test) ** 2)))

plt.figure(figsize=(20,10))
plt.scatter(x_test, y_test,  color='black')
plt.plot(x_test, y_pred, color='blue', linewidth=3)

plt.xlabel("AIEEE Rank")
plt.ylabel("College Code")
plt.title("Admission Prediction")
plt.show()
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Coefficient: [0.00021998]
# RMSE: 11.64

# %%
col=df.columns.tolist()[4:5]
print(col)
usrip=[]
for i in col:
    print("==================================================")
    usrip.append(eval(input(i+": ")))

userpreddt=model.predict([usrip])
print("You may have chance to get entrance in: ",college[clg_code.index(int(userpreddt[0]))])
# Out:
# ['AIEEE Rank']
# ==================================================
# AIEEE Rank: 10
# You may have chance to get entrance in:  IIT kharagpur

# %% [markdown]
#  # *ALL STATE CUMMULATIVE JOB PREDICTION*

# %%
#import packages
import pandas as pd
import numpy as np
import seaborn as sns

#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#for normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

#read the file
df = pd.read_csv('/content/drive/MyDrive/Jobs_and_admission_prediction/ML/GKD_JOBS_ALL_ENGG.csv')

#print the head
df.head()
# Out:
#   CollegeState                           Specialization  GraduationYear  \
# 0        Delhi  instrumentation and control engineering            2013
# 1        Delhi           computer science & engineering            2013
# 2        Delhi           computer science & engineering            2013
# 3        Delhi           computer science & engineering            2013
# 4        Delhi           computer science & engineering            2013
#
#    Salary
# 0  445000
# 1  420000
# 2  200000
# 3  375000
# 4  350000

# %%
data=df
plt.figure(figsize=[20, 7.5]) # Set dimensions for figure
sns.barplot(x=data['GraduationYear'], y=data['Salary'], hue='CollegeState', data=data)
df.shape
# Out:
# (163, 4)

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

#creating dataframe
data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['GraduationYear', 'Salary'])
for i in range(0,len(data)):
    new_data['GraduationYear'][i] = data['GraduationYear'][i]
    new_data['Salary'][i] = data['Salary'][i]

#setting index
new_data.index = new_data.GraduationYear
new_data.drop('GraduationYear', axis=1, inplace=True)

#creating train and test sets
dataset = new_data.values

# train = dataset[4:7,:]
# valid = dataset[7:8,:]

train = dataset[100:]
test = dataset[100:]
# split into input and outputs
x_train, y_train = train[:,:-1], train[:,:-1]
test_X, test_y = test[:,:-1], test[:,:-1]

# #converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(1,len(train)):
    x_train.append(scaled_data[i-1:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train.shape
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (62, 1, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, GRU
model_gru = Sequential()
model_gru.add(LSTM(128, return_sequences=True,input_shape=(x_train.shape[1], x_train.shape[2])))
model_gru.add(LSTM(units=64, return_sequences=True))
model_gru.add(LSTM(units=16, return_sequences=True))
model_gru.add(LSTM(units=4, return_sequences=False))
model_gru.add(Dense(units=1))

model_gru.compile(loss='mse', optimizer='adam')
model_gru.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 1, 128)            66560
#
#  lstm_21 (LSTM)              (None, 1, 64)             49408
#
#  lstm_22 (LSTM)              (None, 1, 16)             5184
#
#  lstm_23 (LSTM)              (None, 4)                 336
#
#  dense_6 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 121493 (474.58 KB)
# Trainable params: 121493 (474.58 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
gru_history = model_gru.fit(x_train, y_train, epochs=100, batch_size=32)
# Save the model
model_gru.save('/content/drive/MyDrive/Jobs_and_admission_prediction/ML/model_gru.h5')
# Out:
# Epoch 1/100
# 2/2 [==============================] - 17s 24ms/step - loss: 0.1039
# Epoch 2/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1018
# Epoch 3/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0999
# Epoch 4/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0978
# Epoch 5/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0957
# Epoch 6/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0937
# Epoch 7/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0915
# Epoch 8/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0893
# Epoch 9/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0871
# Epoch 10/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0847
# Epoch 11/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0823
# Epoch 12/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0797
# Epoch 13/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0771
# Epoch 14/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0743
# Epoch 15/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0713
# Epoch 16/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0681
# Epoch 17/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0647
# Epoch 18/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0611
# Epoch 19/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0573
# Epoch 20/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0532
# Epoch 21/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0490
# Epoch 22/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0450
# Epoch 23/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0404
# Epoch 24/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0366
# Epoch 25/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0328
# Epoch 26/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0300
# Epoch 27/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0278
# Epoch 28/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0272
# Epoch 29/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0280
# Epoch 30/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0292
# Epoch 31/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0296
# Epoch 32/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0294
# Epoch 33/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0288
# Epoch 34/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0281
# Epoch 35/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0277
# Epoch 36/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0273
# Epoch 37/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0272
# Epoch 38/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0274
# Epoch 39/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0274
# Epoch 40/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0275
# Epoch 41/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0275
# Epoch 42/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0274
# Epoch 43/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0274
# Epoch 44/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0272
# Epoch 45/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0273
# Epoch 46/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0271
# Epoch 47/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0271
# Epoch 48/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0271
# Epoch 49/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0271
# Epoch 50/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0271
# Epoch 51/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0271
# Epoch 52/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0271
# Epoch 53/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0271
# Epoch 54/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0270
# Epoch 55/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0270
# Epoch 56/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0270
# Epoch 57/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0270
# Epoch 58/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0270
# Epoch 59/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0270
# Epoch 60/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0270
# Epoch 61/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0270
# Epoch 62/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0269
# Epoch 63/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0269
# Epoch 64/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0269
# Epoch 65/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0269
# Epoch 66/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0269
# Epoch 67/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0269
# Epoch 68/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0269
# Epoch 69/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0269
# Epoch 70/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0269
# Epoch 71/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0269
# Epoch 72/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0269
# Epoch 73/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0268
# Epoch 74/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0268
# Epoch 75/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0268
# Epoch 76/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0269
# Epoch 77/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0268
# Epoch 78/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0268
# Epoch 79/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0268
# Epoch 80/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0268
# Epoch 81/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0268
# Epoch 82/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0268
# Epoch 83/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0268
# Epoch 84/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0268
# Epoch 85/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0268
# Epoch 86/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0268
# Epoch 87/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0268
# Epoch 88/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0268
# Epoch 89/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0268
# Epoch 90/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0267
# Epoch 91/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0267
# Epoch 92/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0267
# Epoch 93/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0267
# Epoch 94/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0267
# Epoch 95/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0267
# Epoch 96/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0267
# Epoch 97/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0267
# Epoch 98/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0267
# Epoch 99/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0267
# Epoch 100/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0267
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the saved model
from tensorflow.keras.models import load_model

# Specify the path to your saved model file
saved_model_path = "/content/drive/MyDrive/Jobs_and_admission_prediction/ML/model_gru.h5"
loaded_model = load_model(saved_model_path)

# Predicting values using the loaded model
inputs = new_data[len(new_data) - len(test) - 10:].values
inputs = inputs.reshape(-1, 1)
inputs = scaler.transform(inputs)

test_x = []
for i in range(1, inputs.shape[0]):
    test_x.append(inputs[i-1:i, 0])
test_x = np.array(test_x)
test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], 1))

# Predict using the loaded model
predicted = loaded_model.predict(test_x)
predicted = scaler.inverse_transform(predicted)

# Plotting the results
b = len(test_x)
c = len(predicted) + b
plt.figure(figsize=(10, 5))
plt.plot(df.iloc[70:, 3:4])
plt.plot(np.arange(b, c), np.array(predicted), label='Prediction', color='orange')
# plt.xlabel('Year')
plt.ylabel('Salary')
plt.title('Cumulative salary of Engineering')
plt.show()
# Out:
# 3/3 [==============================] - 5s 7ms/step

# %%
# predicting values, using past 10 from the train data
inputs = new_data[len(new_data) - len(test) - 10:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

test_x = []
for i in range(1,inputs.shape[0]):
    test_x.append(inputs[i-1:i,0])
test_x = np.array(test_x)
test_x.shape
test_x = np.reshape(test_x, (test_x.shape[0],test_x.shape[1], 1))
test_x.shape
# Out:
# (72, 1, 1)

# %%
predicted = model_gru.predict(test_x)
predicted = scaler.inverse_transform(predicted)
# Out:
# 3/3 [==============================] - 2s 6ms/step

# %%
b=len(test_x)
c=len(predicted) + b
plt.figure(figsize=(10,5))
plt.plot(df.iloc[70:,3:4])
plt.plot(np.arange(b,c), np.array(predicted),label='Prediction', color='orange')
# plt.xlabel('Year')
plt.ylabel('Salary')
plt.title('Cumulative salary of Engineering')
# Out:
# Text(0.5, 1.0, 'Cumulative salary of Engineering')

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(b,c), np.array(predicted), label='Prediction', color='green')
plt.xlabel('Year')
plt.ylabel('Salary')
plt.title('Prediction of Cumulative salary of Engineering')
# Out:
# Text(0.5, 1.0, 'Prediction of Cumulative salary of Engineering')

# %% [markdown]
# # *DELHI STATE SALARY PREDICTION*

# %%
#import packages
import pandas as pd
import numpy as np
import seaborn as sns

#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#for normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

#read the file
df = pd.read_csv('/content/drive/MyDrive/Jobs_and_admission_prediction/ML/GKD_JOBS_ALL_ENGG.csv')

#print the head
df.head()
# Out:
#   CollegeState                           Specialization  GraduationYear  \
# 0        Delhi  instrumentation and control engineering            2013
# 1        Delhi           computer science & engineering            2013
# 2        Delhi           computer science & engineering            2013
# 3        Delhi           computer science & engineering            2013
# 4        Delhi           computer science & engineering            2013
#
#    Salary
# 0  445000
# 1  420000
# 2  200000
# 3  375000
# 4  350000

# %%
data=df.iloc[:122,:]
plt.figure(figsize=[12, 7.5]) # Set dimensions for figure
sns.barplot(x=data['GraduationYear'], y=data['Salary'], hue='CollegeState', data=data)
# Out:
# <Axes: xlabel='GraduationYear', ylabel='Salary'>

# %%
data=df.iloc[139:,:]
plt.figure(figsize=[12, 7.5]) # Set dimensions for figure
sns.barplot(x=data['GraduationYear'], y=data['Salary'], hue='Specialization', data=data)
df.shape
# Out:
# (163, 4)

# %%
dff = df.iloc[:122,:]
dff.shape
# Out:
# (122, 4)

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

#creating dataframe
data_data = dff.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(dff)),columns=['GraduationYear', 'Salary'])
for i in range(0,len(data_data)):
    new_data['GraduationYear'][i] = data_data['GraduationYear'][i]
    new_data['Salary'][i] = data_data['Salary'][i]

#setting index
new_data.index = new_data.GraduationYear
new_data.drop('GraduationYear', axis=1, inplace=True)

#creating train and test sets
dataset = new_data.values

# train = dataset[4:7,:]
# valid = dataset[7:8,:]

train = dataset[:90]
test = dataset[90:]
# split into input and outputs
x_train, y_train = train[:,:-1], train[:,:-1]
test_X, test_y = test[:,:-1], test[:,:-1]

# #converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(1,len(train)):
    x_train.append(scaled_data[i-1:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

# train.shape
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (89, 1, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, GRU
model_gru = Sequential()
model_gru.add(GRU(128, return_sequences=True,input_shape=(x_train.shape[1], x_train.shape[2])))
model_gru.add(GRU(units=64, return_sequences=True))
model_gru.add(GRU(units=16, return_sequences=True))
model_gru.add(GRU(units=4, return_sequences=False))
model_gru.add(Dense(units=1))

model_gru.compile(loss='mse', optimizer='adam')
model_gru.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 1, 128)            50304
#
#  gru_1 (GRU)                 (None, 1, 64)             37248
#
#  gru_2 (GRU)                 (None, 1, 16)             3936
#
#  gru_3 (GRU)                 (None, 4)                 264
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 91757 (358.43 KB)
# Trainable params: 91757 (358.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
gru_history = model_gru.fit(x_train, y_train, epochs=100, batch_size=32)
model_gru.save('/content/drive/MyDrive/Jobs_and_admission_prediction/ML/model_gruDdelhi.h5')
# Out:
# Epoch 1/100
# 3/3 [==============================] - 8s 10ms/step - loss: 0.0829
# Epoch 2/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0727
# Epoch 3/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0626
# Epoch 4/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0523
# Epoch 5/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0411
# Epoch 6/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0321
# Epoch 7/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0261
# Epoch 8/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0229
# Epoch 9/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0246
# Epoch 10/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0260
# Epoch 11/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0252
# Epoch 12/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0235
# Epoch 13/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0229
# Epoch 14/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0229
# Epoch 15/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0230
# Epoch 16/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0231
# Epoch 17/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0230
# Epoch 18/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0228
# Epoch 19/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0226
# Epoch 20/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0225
# Epoch 21/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0227
# Epoch 22/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0226
# Epoch 23/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0226
# Epoch 24/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0226
# Epoch 25/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 26/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 27/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0225
# Epoch 28/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 29/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0225
# Epoch 30/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 31/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0224
# Epoch 32/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0224
# Epoch 33/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 34/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0223
# Epoch 35/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0223
# Epoch 36/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0223
# Epoch 37/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 38/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0223
# Epoch 39/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0223
# Epoch 40/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0223
# Epoch 41/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0223
# Epoch 42/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0223
# Epoch 43/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0222
# Epoch 44/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0222
# Epoch 45/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0222
# Epoch 46/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0222
# Epoch 47/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0222
# Epoch 48/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0222
# Epoch 49/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0222
# Epoch 50/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0222
# Epoch 51/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0222
# Epoch 52/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0222
# Epoch 53/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0222
# Epoch 54/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0222
# Epoch 55/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0221
# Epoch 56/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0221
# Epoch 57/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0221
# Epoch 58/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0221
# Epoch 59/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0221
# Epoch 60/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0221
# Epoch 61/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0221
# Epoch 62/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0221
# Epoch 63/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0221
# Epoch 64/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0221
# Epoch 65/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0221
# Epoch 66/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0221
# Epoch 67/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0221
# Epoch 68/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0221
# Epoch 69/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0221
# Epoch 70/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 71/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 72/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 73/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 74/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 75/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 76/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 77/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0220
# Epoch 78/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 79/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 80/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0222
# Epoch 81/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0221
# Epoch 82/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 83/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0220
# Epoch 84/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 85/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 86/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0220
# Epoch 87/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 88/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0222
# Epoch 89/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 90/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0222
# Epoch 91/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 92/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0220
# Epoch 93/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0220
# Epoch 94/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 95/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0222
# Epoch 96/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0221
# Epoch 97/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0220
# Epoch 98/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0220
# Epoch 99/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0221
# Epoch 100/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0221
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# predicting values, using past 10 from the train data
inputs = new_data[len(new_data) - len(test) - 1:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

test_x = []
for i in range(1,inputs.shape[0]):
    test_x.append(inputs[i-1:i,0])
test_x = np.array(test_x)
test_x.shape
test_x = np.reshape(test_x, (test_x.shape[0],test_x.shape[1], 1))
test_x.shape
# Out:
# (32, 1, 1)

# %%
predicted = model_gru.predict(test_x)
predicted = scaler.inverse_transform(predicted)
print(b,c)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x79c4ed7ac280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# 72 144

# %%
b=len(test_x)
c=len(predicted) + b
plt.figure(figsize=(10,5))
plt.plot(dff['Salary'])
# plt.plot(np.arange(b,c), np.array(predicted),label='Prediction', color='orange')
plt.xlabel('Graduation Year')
plt.ylabel('Salary')
plt.title('Cumulative salary of Engineering (DELHI)')
# Out:
# Text(0.5, 1.0, 'Cumulative salary of Engineering (DELHI)')

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(b,c), np.array(predicted), label='Prediction', color='green')
plt.xlabel(' Graduation Year')
plt.ylabel('Salary')
plt.title('Prediction of Cumulative salary of Engineering (DELHI)')
# Out:
# Text(0.5, 1.0, 'Prediction of Cumulative salary of Engineering (DELHI)')
